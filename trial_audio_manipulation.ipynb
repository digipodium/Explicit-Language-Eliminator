# %%
# from youtube_transcript_api import YouTubeTranscriptApi
# from better_profanity import profanity
# from pytube import YouTube
# import moviepy
# import moviepy.editor as mp
# import os
import Youtube_functions as yf

# %%
link='https://www.youtube.com/watch?v=ImEnWAVRLU0&t=50s'
path="downloads_yt/audios"

# %%
f=yf.explicit_language_timestamps(yf.clean_transcript('https://www.youtube.com/watch?v=ImEnWAVRLU0'))
# Out:
# File Already Exists!

# %%
f[0]
# Out:
# {'text': "bar I'd say you're full of ****", 'start': 317.71, 'duration': 5.64}

# %%
from pydub import AudioSegment
# import ffprobe

# %%
path='downloads_yt/audios/Mike_Ross_Interview_with_Harvey_Specter__Suits.mp3'

# %%
song = AudioSegment.from_mp3(path)

# %%
song.export('wav_form.wav', format="wav")
# Out:
# <_io.BufferedRandom name='wav_form.wav'>

# %% [raw]
# clip_start=(f[0]['start']+duration*2)*1000

# %%
clip_start=f[0]['start']*1000

# %%
clip_end=(f[0]['start']+f[0]['duration'])*1000

# %%
len(f[0]['text'].split())
# Out:
# 7

# %%
duration=f[0]['duration']/len(f[0]['text'].split())

# %%
clip_start
# Out:
# 317710.0

# %%
vol=song[clip_start:clip_end]

# %%
vol
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
import speech_recognition as speech_recog

# %%
sample_audio = speech_recog.AudioFile('wav_form.wav')

# %%
with sample_audio as audio_file:
    recog=speech_recog.Recognizer()
    audio_content = recog.record(audio_file, offset=f[0]['start'], duration=f[0]['duration'])

recog.recognize_google(audio_content)
# Out:
# "it's a UFO trap as Barbie nigohan"
